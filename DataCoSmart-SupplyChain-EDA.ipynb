# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('DataCoSupplyChainDataset.csv',encoding='latin-1')
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
df_info=pd.read_csv('DescriptionDataCoSupplyChain.csv')
df_info
# Out:
#                            FIELDS  \
# 0                            Type
# 1   Days for shipping (real)
# 2   Days for shipment (scheduled)
# 3               Benefit per order
# 4              Sales per customer
# 5                 Delivery Status
# 6   Late_delivery_risk
# 7                     Category Id
# 8                   Category Name
# 9                   Customer City
# 10               Customer Country
# 11                 Customer Email
# 12                 Customer Fname
# 13                    Customer Id
# 14                 Customer Lname
# 15              Customer Password
# 16               Customer Segment
# 17                 Customer State
# 18                Customer Street
# 19               Customer Zipcode
# 20                  Department Id
# 21                Department Name
# 22                       Latitude
# 23                      Longitude
# 24                         Market
# 25                     Order City
# 26                  Order Country
# ...

# %%
df.shape
# Out:
# (180519, 53)

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# std           104.433526          120.043670            0.497664
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap="viridis")
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %%
df['Customer Full Name']=df['Customer Fname'].astype(str)+df['Customer Lname'].astype(str)
df.drop('Customer Lname',axis=1,inplace=True)
df.drop('Product Description',axis=1,inplace=True)
df['Customer Zipcode']=df['Customer Zipcode'].fillna(0)
df.drop('Order Zipcode',axis=1,inplace=True)

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap="viridis")
# Out:
# <Axes: >

# %%
data=df[(df['Order Country']=='India') & (df['Order Status']=='PENDING')]

# %%
data
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 1       TRANSFER                         5                              4
# 21      TRANSFER                         5                              4
# 45      TRANSFER                         6                              4
# 46      TRANSFER                         5                              2
# 382     TRANSFER                         3                              4
# ...          ...                       ...                            ...
# 180142  TRANSFER                         4                              4
# 180164  TRANSFER                         2                              1
# 180248  TRANSFER                         5                              2
# 180331  TRANSFER                         3                              4
# 180405  TRANSFER                         2                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
data1=data[['Order City','Order Country','Order Status','Product Name']]
data1.head()
# Out:
#      Order City Order Country     Order Status  \
# 407   Bangalore         India  SUSPECTED_FRAUD
# 1893    Nellore         India  SUSPECTED_FRAUD
# 1894    Nellore         India  SUSPECTED_FRAUD
# 1895    Nellore         India  SUSPECTED_FRAUD
# 5572       Pune         India  SUSPECTED_FRAUD
#
#                             Product Name
# 407                         Smart watch
# 1893    Perfect Fitness Perfect Rip Deck
# 1894    Perfect Fitness Perfect Rip Deck
# 1895    Perfect Fitness Perfect Rip Deck
# 5572  Nike Women's Legend V-Neck T-Shirt

# %%
data1=data1['Order City'].value_counts().plot.bar(figsize=(20,8), title="Cities with Pending Status")

# %%
data=df[(df['Order Country']=='India') & (df['Order Status']=='SUSPECTED_FRAUD')]

# %%
data
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 407     TRANSFER                         3                              2
# 1893    TRANSFER                         6                              4
# 1894    TRANSFER                         6                              4
# 1895    TRANSFER                         6                              4
# 5572    TRANSFER                         5                              2
# ...          ...                       ...                            ...
# 172257  TRANSFER                         4                              4
# 177428  TRANSFER                         6                              4
# 179916  TRANSFER                         3                              4
# 180406  TRANSFER                         6                              4
# 180490  TRANSFER                         4                              4
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
data2=data[['Order City','Order Country','Order Status','Product Name']]
data2.head()
# Out:
#      Order City Order Country     Order Status  \
# 407   Bangalore         India  SUSPECTED_FRAUD
# 1893    Nellore         India  SUSPECTED_FRAUD
# 1894    Nellore         India  SUSPECTED_FRAUD
# 1895    Nellore         India  SUSPECTED_FRAUD
# 5572       Pune         India  SUSPECTED_FRAUD
#
#                             Product Name
# 407                         Smart watch
# 1893    Perfect Fitness Perfect Rip Deck
# 1894    Perfect Fitness Perfect Rip Deck
# 1895    Perfect Fitness Perfect Rip Deck
# 5572  Nike Women's Legend V-Neck T-Shirt

# %%
data2=data2['Order City'].value_counts().plot.bar(figsize=(20,8), title="Cities with Suspected_Fraud Status")

# %%
data=df[df['Order Status']=='PENDING']
data3=data['Order Country'].value_counts().nlargest(10).plot.bar(figsize=(20,8), title="Countries with highest Pending Status")

# %%
data=df[df['Order Status']=='SUSPECTED_FRAUD']
data3=data['Order Country'].value_counts().nlargest(10).plot.bar(figsize=(20,8), title="Countries with highest Fraud Status")

# %%
max_discount = df['Order Item Discount'].max()
data4=df[df['Order Item Discount']==max_discount]
data4[['Product Name','Order Item Discount']]
# Out:
#               Product Name  Order Item Discount
# 12606  SOLE E35 Elliptical                500.0

# %%
data4[['Product Name','Order Item Discount']].value_counts().nlargest(10).plot.bar(figsize=(20,8), title="No Of Products Discounted On Max Discount")
# Out:
# <Axes: title={'center': 'No Of Products Discounted On Max Discount'}, xlabel='Product Name,Order Item Discount'>

# %%
min_discount = df['Order Item Discount'].min()
data5=df[df['Order Item Discount']==min_discount]
data5[['Product Name','Order Item Discount']]
# Out:
#                                      Product Name  Order Item Discount
# 14                                   Smart watch                   0.0
# 32                                   Smart watch                   0.0
# 74              Nike Men's Free 5.0+ Running Shoe                  0.0
# 82           Nike Men's Dri-FIT Victory Golf Polo                  0.0
# 120             Nike Men's Free 5.0+ Running Shoe                  0.0
# ...                                           ...                  ...
# 180442  Field & Stream Sportsman 16 Gun Fire Safe                  0.0
# 180460  Field & Stream Sportsman 16 Gun Fire Safe                  0.0
# 180478  Field & Stream Sportsman 16 Gun Fire Safe                  0.0
# 180496  Field & Stream Sportsman 16 Gun Fire Safe                  0.0
# 180514  Field & Stream Sportsman 16 Gun Fire Safe                  0.0
#
# [10028 rows x 2 columns]

# %%
data5[['Product Name','Order Item Discount']].value_counts().nlargest(10).plot.bar(figsize=(20,8), title="No Of Products Discounted On Min Discount")
# Out:
# <Axes: title={'center': 'No Of Products Discounted On Min Discount'}, xlabel='Product Name,Order Item Discount'>

# %%
def fun(row):
    if(row.startswith('Nike')):
        return 'Nike'
    else:
        return row
df['Product Name'] =df['Product Name'].apply(fun)
df['shipping date (DateOrders)'] = pd.to_datetime(df['shipping date (DateOrders)'], format='%m/%d/%Y %H:%M')
df['Year'] = pd.DatetimeIndex(df['shipping date (DateOrders)']).year
data6 = df[df['Product Name']=='Nike']
sns.countplot(x ='Product Name', data = data6,hue='Year').set(title='Yearly Sales', xlabel='', ylabel='Sales')
# Out:
# [Text(0.5, 1.0, 'Yearly Sales'), Text(0.5, 0, ''), Text(0, 0.5, 'Sales')]

# %%
data7=df[(df["Days for shipping (real)"] < df["Days for shipment (scheduled)"]) & (df['Order Status']=='COMPLETE')|(df['Order Status']=='CLOSED')]
data7
# Out:
#          Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0       DEBIT                         3                              4
# 2        CASH                         4                              4
# 3       DEBIT                         3                              4
# 8        CASH                         3                              2
# 9        CASH                         2                              1
# ...       ...                       ...                            ...
# 180498   CASH                         3                              4
# 180500  DEBIT                         3                              4
# 180504   CASH                         3                              4
# 180505  DEBIT                         2                              4
# 180514   CASH                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
data7[['Product Name','Type','Shipping Mode']].value_counts()
# Out:
# Product Name                                   Type   Shipping Mode
# Nike                                           DEBIT  Standard Class    4531
#                                                CASH   Standard Class    3790
# Perfect Fitness Perfect Rip Deck               DEBIT  Standard Class    1880
#                                                CASH   Standard Class    1535
# O'Brien Men's Neoprene Life Vest               DEBIT  Standard Class    1512
#                                                                         ...
# Under Armour Women's Micro G Skulpt Running S  CASH   Same Day             1
# Polar FT4 Heart Rate Monitor                   CASH   Second Class         1
#                                                       Same Day             1
# Glove It Women's Mod Oval 3-Zip Carry All Gol  CASH   Same Day             1
# Team Golf San Francisco Giants Putter Grip     CASH   Same Day             1
# Length: 445, dtype: int64
